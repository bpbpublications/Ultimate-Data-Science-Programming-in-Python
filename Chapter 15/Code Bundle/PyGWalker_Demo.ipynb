# %%
import pandas as mypd

# %%
import pygwalker as mypg

# %%
mypg.__version__
# Out:
# '0.3.9'

# %%
mydf = mypd.read_csv("tips.csv")

# %%
mydf.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# In Jupyter Notebook, preceding a function or method name with "??" serves as a shortcut to retrieve its source code, 
# offering a convenient means to access the implementation details directly within the notebook environment, 
# provided the source code is available.
??mypg.walk

# %%
# exploring the data
mypg.walk(mydf, dark='light', hideDataSourceConfig=True, vegaTheme='vega')
# dark='light': lighter color mode is used
# hideDataSourceConfig=True : When set to True, it indicates that the exploration process will hide the specifics of the data source configuration, 
# such as file paths or database connection settings, ensuring a cleaner and more focused display of the data analysis results.
# vegaTheme='vega' : Allows expressive and interactive visualizations creation.
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-0">
#         <div class="tabs">
#
#         </div>
#     </div>
# </body>
# </html>

# %%
vis_spec = r"""{"config":"[{\"visId\":\"gw_3lCC\",\"name\":\"Chart 1\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_tDQL\",\"fid\":\"GW_6BOPIDRK\",\"name\":\"sex\",\"basename\":\"sex\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_WA0B\",\"fid\":\"GW_1R6WPNO37T7OW\",\"name\":\"smoker\",\"basename\":\"smoker\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_nSJo\",\"fid\":\"GW_5I24WL68\",\"name\":\"day\",\"basename\":\"day\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_Sjki\",\"fid\":\"GW_19DCMEDB1S\",\"name\":\"time\",\"basename\":\"time\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_Ir7T\",\"fid\":\"GW_18ZBM3DZCG\",\"name\":\"size\",\"basename\":\"size\",\"semanticType\":\"quantitative\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_mea_key_fid\",\"fid\":\"gw_mea_key_fid\",\"name\":\"Measure names\",\"analyticType\":\"dimension\",\"semanticType\":\"nominal\"}],\"measures\":[{\"dragId\":\"gw_xnhF\",\"fid\":\"GW_3HRRSA0VIWPA37PHIY8\",\"name\":\"total_bill\",\"basename\":\"total_bill\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_TiPg\",\"fid\":\"GW_6DOU9KQ8\",\"name\":\"tip\",\"basename\":\"tip\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}},{\"dragId\":\"gw_mea_val_fid\",\"fid\":\"gw_mea_val_fid\",\"name\":\"Measure values\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"rows\":[{\"dragId\":\"gw_1zzk\",\"fid\":\"GW_3HRRSA0VIWPA37PHIY8\",\"name\":\"total_bill\",\"basename\":\"total_bill\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"max\"}],\"columns\":[{\"dragId\":\"gw_lNfE\",\"fid\":\"GW_5I24WL68\",\"name\":\"day\",\"basename\":\"day\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"color\":[],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"fixed\",\"width\":546,\"height\":232},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1}},{\"visId\":\"gw_A_7j\",\"name\":\"Chart 2\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_G8HD\",\"fid\":\"GW_6BOPIDRK\",\"name\":\"sex\",\"basename\":\"sex\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_jSHI\",\"fid\":\"GW_1R6WPNO37T7OW\",\"name\":\"smoker\",\"basename\":\"smoker\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_omJs\",\"fid\":\"GW_5I24WL68\",\"name\":\"day\",\"basename\":\"day\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_7pqQ\",\"fid\":\"GW_19DCMEDB1S\",\"name\":\"time\",\"basename\":\"time\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_0aiL\",\"fid\":\"GW_18ZBM3DZCG\",\"name\":\"size\",\"basename\":\"size\",\"semanticType\":\"quantitative\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_mea_key_fid\",\"fid\":\"gw_mea_key_fid\",\"name\":\"Measure names\",\"analyticType\":\"dimension\",\"semanticType\":\"nominal\"}],\"measures\":[{\"dragId\":\"gw_FfXB\",\"fid\":\"GW_3HRRSA0VIWPA37PHIY8\",\"name\":\"total_bill\",\"basename\":\"total_bill\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_DnGa\",\"fid\":\"GW_6DOU9KQ8\",\"name\":\"tip\",\"basename\":\"tip\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}},{\"dragId\":\"gw_mea_val_fid\",\"fid\":\"gw_mea_val_fid\",\"name\":\"Measure values\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"rows\":[{\"dragId\":\"gw_NbEA\",\"fid\":\"GW_3HRRSA0VIWPA37PHIY8\",\"name\":\"total_bill\",\"basename\":\"total_bill\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"columns\":[{\"dragId\":\"gw_OmzM\",\"fid\":\"GW_1R6WPNO37T7OW\",\"name\":\"smoker\",\"basename\":\"smoker\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_jsCM\",\"fid\":\"GW_5I24WL68\",\"name\":\"day\",\"basename\":\"day\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"color\":[{\"dragId\":\"gw_JEOR\",\"fid\":\"GW_19DCMEDB1S\",\"name\":\"time\",\"basename\":\"time\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[{\"dragId\":\"gw_xYoH\",\"fid\":\"GW_6BOPIDRK\",\"name\":\"sex\",\"basename\":\"sex\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\",\"rule\":{\"type\":\"one of\",\"value\":[\"Female\"]}}],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"auto\",\"width\":320,\"height\":200},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1}}]","chart_map":{},"version":"0.3.9"}"""
mypg.walk(mydf, spec=vis_spec, dark='light', hideDataSourceConfig=True, vegaTheme='vega')
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-1" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-1">
#         <div class="tabs">
#
#             <div class="tab-pane">
#
#                 <input type="radio" name="tab-pyg-1" id="tab-1-Chart1" checked />
#
# ...

# %%
# %pip show pygwalker
# Out:
# Name: pygwalker
# Version: 0.3.9
# Summary: pygwalker: Combining Jupyter Notebook with a Tableau-like UI
# Home-page:
# Author:
# Author-email: kanaries <support@kanaries.net>
# License:
# Location: c:\users\saurabh\anaconda3\lib\site-packages
# Requires: arrow, astor, duckdb, gw-dsl-parser, ipython, ipywidgets, jinja2, psutil, pyarrow, pydantic, requests, sqlalchemy, sqlglot, typing-extensions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cipy (c:\users\saurabh\anaconda3\lib\site-packages)
